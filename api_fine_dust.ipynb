# %%
import requests

# %%
url = 'http://apis.data.go.kr/B552584/UlfptcaAlarmInqireSvc/getUlfptcaAlarmInfo'

service_key = '1qjdiDvTA90Yng9EREAc9b6t76C5jMhSKPn2ZbE3mR/WZe4wxZGNYWpeIa4gUqnlwEEPLvcVizCIZzMJ3FXJXQ=='

params ={'serviceKey' : service_key, 'returnType' : 'xml', 'numOfRows' : '100', 'pageNo' : '1', 'year' : '2020', 'itemCode' : 'PM10' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n<response>\n  <header>\n    <resultCode>00</resultCode>\n    <resultMsg>NORMAL_CODE</resultMsg>\n  </header>\n  <body>\n    <items>\n      <item>\n        <clearVal>65</clearVal>\n        <sn>249</sn>\n        <districtName>\xec\xa0\x84\xeb\xb6\x81</districtName>\n        <dataDate>2020-10-22</dataDate>\n        <issueVal>196</issueVal>\n        <issueTime>17:00</issueTime>\n        <clearDate>2020-10-22</clearDate>\n        <issueDate>2020-10-22</issueDate>\n        <moveName>\xec\x9e\x84\xec\x8b\xa4\xea\xb6\x8c\xec\x97\xad</moveName>\n        <clearTime>19:00</clearTime>\n        <issueGbn>\xec\xa3\xbc\xec\x9d\x98\xeb\xb3\xb4</issueGbn>\n        <itemCode>PM10</itemCode>\n      </item>\n      <item>\n        <clearVal>76</clearVal>\n        <sn>248</sn>\n        <districtName>\xec\xa0\x84\xeb\xb6\x81</districtName>\n        <dataDate>2020-10-22</dataDate>\n        <issueVal>179</issueVal>\n        <issueTime>17:00</issueTime>\n        <cl
# ...

# %%
response.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\r\n<response>\n  <header>\n    <resultCode>00</resultCode>\n    <resultMsg>NORMAL_CODE</resultMsg>\n  </header>\n  <body>\n    <items>\n      <item>\n        <clearVal>65</clearVal>\n        <sn>249</sn>\n        <districtName>전북</districtName>\n        <dataDate>2020-10-22</dataDate>\n        <issueVal>196</issueVal>\n        <issueTime>17:00</issueTime>\n        <clearDate>2020-10-22</clearDate>\n        <issueDate>2020-10-22</issueDate>\n        <moveName>임실권역</moveName>\n        <clearTime>19:00</clearTime>\n        <issueGbn>주의보</issueGbn>\n        <itemCode>PM10</itemCode>\n      </item>\n      <item>\n        <clearVal>76</clearVal>\n        <sn>248</sn>\n        <districtName>전북</districtName>\n        <dataDate>2020-10-22</dataDate>\n        <issueVal>179</issueVal>\n        <issueTime>17:00</issueTime>\n        <clearDate>2020-10-22</clearDate>\n        <issueDate>2020-10-22</issueDate>\n        <moveName>전주권역</moveName>\n        <cle
# ...

# %%
from bs4 import BeautifulSoup

xml = BeautifulSoup(response.text, features='xml')
xml
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
# <header>
# <resultCode>00</resultCode>
# <resultMsg>NORMAL_CODE</resultMsg>
# </header>
# <body>
# <items>
# <item>
# <clearVal>65</clearVal>
# <sn>249</sn>
# <districtName>전북</districtName>
# <dataDate>2020-10-22</dataDate>
# <issueVal>196</issueVal>
# <issueTime>17:00</issueTime>
# <clearDate>2020-10-22</clearDate>
# <issueDate>2020-10-22</issueDate>
# <moveName>임실권역</moveName>
# <clearTime>19:00</clearTime>
# <issueGbn>주의보</issueGbn>
# <itemCode>PM10</itemCode>
# </item>
# <item>
# <clearVal>76</clearVal>
# <sn>248</sn>
# <districtName>전북</districtName>
# <dataDate>2020-10-22</dataDate>
# <issueVal>179</issueVal>
# <issueTime>17:00</issueTime>
# <clearDate>2020-10-22</clearDate>
# <issueDate>2020-10-22</issueDate>
# <moveName>전주권역</moveName>
# <clearTime>19:00</clearTime>
# <issueGbn>주의보</issueGbn>
# <itemCode>PM10</itemCode>
# </item>
# <item>
# <clearVal>95</clearVal>
# <sn>241</sn>
# <districtName>경기</districtName>
# ...

# %%
xml.resultMsg
# Out:
# <resultMsg>NORMAL_CODE</resultMsg>

# %%
# !pip install xmltodict

# %%
import xmltodict

parsing_dict = xmltodict.parse(response.text)

# %%
parsing_dict
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'},
#   'body': {'items': {'item': [{'clearVal': '65',
#       'sn': '249',
#       'districtName': '전북',
#       'dataDate': '2020-10-22',
#       'issueVal': '196',
#       'issueTime': '17:00',
#       'clearDate': '2020-10-22',
#       'issueDate': '2020-10-22',
#       'moveName': '임실권역',
#       'clearTime': '19:00',
#       'issueGbn': '주의보',
#       'itemCode': 'PM10'},
#      {'clearVal': '76',
#       'sn': '248',
#       'districtName': '전북',
#       'dataDate': '2020-10-22',
#       'issueVal': '179',
#       'issueTime': '17:00',
#       'clearDate': '2020-10-22',
#       'issueDate': '2020-10-22',
#       'moveName': '전주권역',
#       'clearTime': '19:00',
#       'issueGbn': '주의보',
#       'itemCode': 'PM10'},
#      {'clearVal': '95',
#       'sn': '241',
#       'districtName': '경기',
#       'dataDate': '2020-10-22',
#       'issueVal': '162',
#       'issueTime': '16:00',
# ...

# %%
parsing_dict.keys()
# Out:
# dict_keys(['response'])

# %%
parsing_dict['response']
# Out:
# {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'},
#  'body': {'items': {'item': [{'clearVal': '65',
#      'sn': '249',
#      'districtName': '전북',
#      'dataDate': '2020-10-22',
#      'issueVal': '196',
#      'issueTime': '17:00',
#      'clearDate': '2020-10-22',
#      'issueDate': '2020-10-22',
#      'moveName': '임실권역',
#      'clearTime': '19:00',
#      'issueGbn': '주의보',
#      'itemCode': 'PM10'},
#     {'clearVal': '76',
#      'sn': '248',
#      'districtName': '전북',
#      'dataDate': '2020-10-22',
#      'issueVal': '179',
#      'issueTime': '17:00',
#      'clearDate': '2020-10-22',
#      'issueDate': '2020-10-22',
#      'moveName': '전주권역',
#      'clearTime': '19:00',
#      'issueGbn': '주의보',
#      'itemCode': 'PM10'},
#     {'clearVal': '95',
#      'sn': '241',
#      'districtName': '경기',
#      'dataDate': '2020-10-22',
#      'issueVal': '162',
#      'issueTime': '16:00',
#      'clearDate': '2020-10-22',
#      'issueDate': '2020-10-22',
# ...

# %%
parsing_dict['response'].keys()
# Out:
# dict_keys(['header', 'body'])

# %%
parsing_dict['response']['body']
# Out:
# {'items': {'item': [{'clearVal': '65',
#     'sn': '249',
#     'districtName': '전북',
#     'dataDate': '2020-10-22',
#     'issueVal': '196',
#     'issueTime': '17:00',
#     'clearDate': '2020-10-22',
#     'issueDate': '2020-10-22',
#     'moveName': '임실권역',
#     'clearTime': '19:00',
#     'issueGbn': '주의보',
#     'itemCode': 'PM10'},
#    {'clearVal': '76',
#     'sn': '248',
#     'districtName': '전북',
#     'dataDate': '2020-10-22',
#     'issueVal': '179',
#     'issueTime': '17:00',
#     'clearDate': '2020-10-22',
#     'issueDate': '2020-10-22',
#     'moveName': '전주권역',
#     'clearTime': '19:00',
#     'issueGbn': '주의보',
#     'itemCode': 'PM10'},
#    {'clearVal': '95',
#     'sn': '241',
#     'districtName': '경기',
#     'dataDate': '2020-10-22',
#     'issueVal': '162',
#     'issueTime': '16:00',
#     'clearDate': '2020-10-22',
#     'issueDate': '2020-10-22',
#     'moveName': '남부권',
#     'clearTime': '18:00',
#     'issueGbn': '주의보',
#     'itemCode': 'PM10'},
# ...

# %%
parsing_dict['response']['body']['items']
# Out:
# {'item': [{'clearVal': '65',
#    'sn': '249',
#    'districtName': '전북',
#    'dataDate': '2020-10-22',
#    'issueVal': '196',
#    'issueTime': '17:00',
#    'clearDate': '2020-10-22',
#    'issueDate': '2020-10-22',
#    'moveName': '임실권역',
#    'clearTime': '19:00',
#    'issueGbn': '주의보',
#    'itemCode': 'PM10'},
#   {'clearVal': '76',
#    'sn': '248',
#    'districtName': '전북',
#    'dataDate': '2020-10-22',
#    'issueVal': '179',
#    'issueTime': '17:00',
#    'clearDate': '2020-10-22',
#    'issueDate': '2020-10-22',
#    'moveName': '전주권역',
#    'clearTime': '19:00',
#    'issueGbn': '주의보',
#    'itemCode': 'PM10'},
#   {'clearVal': '95',
#    'sn': '241',
#    'districtName': '경기',
#    'dataDate': '2020-10-22',
#    'issueVal': '162',
#    'issueTime': '16:00',
#    'clearDate': '2020-10-22',
#    'issueDate': '2020-10-22',
#    'moveName': '남부권',
#    'clearTime': '18:00',
#    'issueGbn': '주의보',
#    'itemCode': 'PM10'},
#   {'clearVal': '88',
#    'sn': '236',
# ...

# %%
parsing_dict['response']['body']['items']['item']
# Out:
# [{'clearVal': '65',
#   'sn': '249',
#   'districtName': '전북',
#   'dataDate': '2020-10-22',
#   'issueVal': '196',
#   'issueTime': '17:00',
#   'clearDate': '2020-10-22',
#   'issueDate': '2020-10-22',
#   'moveName': '임실권역',
#   'clearTime': '19:00',
#   'issueGbn': '주의보',
#   'itemCode': 'PM10'},
#  {'clearVal': '76',
#   'sn': '248',
#   'districtName': '전북',
#   'dataDate': '2020-10-22',
#   'issueVal': '179',
#   'issueTime': '17:00',
#   'clearDate': '2020-10-22',
#   'issueDate': '2020-10-22',
#   'moveName': '전주권역',
#   'clearTime': '19:00',
#   'issueGbn': '주의보',
#   'itemCode': 'PM10'},
#  {'clearVal': '95',
#   'sn': '241',
#   'districtName': '경기',
#   'dataDate': '2020-10-22',
#   'issueVal': '162',
#   'issueTime': '16:00',
#   'clearDate': '2020-10-22',
#   'issueDate': '2020-10-22',
#   'moveName': '남부권',
#   'clearTime': '18:00',
#   'issueGbn': '주의보',
#   'itemCode': 'PM10'},
#  {'clearVal': '88',
#   'sn': '236',
#   'districtName': '경기',
# ...
